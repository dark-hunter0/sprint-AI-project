# %% [markdown]
# ## Importing The Data

# %%
from ucimlrepo import fetch_ucirepo 
  
# fetch dataset 
heart_disease = fetch_ucirepo(id=45) 
  
# data (as pandas dataframes) 
X = heart_disease.data.features 
y = heart_disease.data.targets 
  
# metadata 
print(heart_disease.metadata) 
  
# variable information 
print(heart_disease.variables) 
df = X.copy()
df['num'] = y.copy()
df
# Out:
# {'uci_id': 45, 'name': 'Heart Disease', 'repository_url': 'https://archive.ics.uci.edu/dataset/45/heart+disease', 'data_url': 'https://archive.ics.uci.edu/static/public/45/data.csv', 'abstract': '4 databases: Cleveland, Hungary, Switzerland, and the VA Long Beach', 'area': 'Health and Medicine', 'tasks': ['Classification'], 'characteristics': ['Multivariate'], 'num_instances': 303, 'num_features': 13, 'feature_types': ['Categorical', 'Integer', 'Real'], 'demographics': ['Age', 'Sex'], 'target_col': ['num'], 'index_col': None, 'has_missing_values': 'yes', 'missing_values_symbol': 'NaN', 'year_of_dataset_creation': 1989, 'last_updated': 'Fri Nov 03 2023', 'dataset_doi': '10.24432/C52P4X', 'creators': ['Andras Janosi', 'William Steinbrunn', 'Matthias Pfisterer', 'Robert Detrano'], 'intro_paper': {'ID': 231, 'type': 'NATIVE', 'title': 'International application of a new probability algorithm for the diagnosis of coronary artery disease.', 'authors': 'R. Detrano, A. Jánosi, W. Steinbrunn,
# ...

# %% [markdown]
# ### First look

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trestbps  303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalach   303 non-null    int64
#  8   exang     303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slope     303 non-null    int64
#  11  ca        299 non-null    float64
#  12  thal      301 non-null    float64
#  13  num       303 non-null    int64
# dtypes: float64(3), int64(11)
# memory usage: 33.3 KB

# %%
df.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.438944    0.679868    3.158416  131.689769  246.693069    0.148515
# std      9.038662    0.467299    0.960126   17.599748   51.776918    0.356198
# min     29.000000    0.000000    1.000000   94.000000  126.000000    0.000000
# 25%     48.000000    0.000000    3.000000  120.000000  211.000000    0.000000
# 50%     56.000000    1.000000    3.000000  130.000000  241.000000    0.000000
# 75%     61.000000    1.000000    4.000000  140.000000  275.000000    0.000000
# max     77.000000    1.000000    4.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  299.000000
# mean     0.990099  149.607261    0.326733    1.039604    1.600660    0.672241
# ...

# %%
df.nunique()
# Out:
# age          41
# sex           2
# cp            4
# trestbps     50
# chol        152
# fbs           2
# restecg       3
# thalach      91
# exang         2
# oldpeak      40
# slope         3
# ca            4
# thal          3
# num           5
# dtype: int64

# %% [markdown]
# ### EDA

# %%
plt.figure(figsize=(30, 20))

sns.heatmap(df.corr(), annot=True, cmap='coolwarm', fmt='.2f')
# Out:
# <Axes: >

# %%
df.corr()['num']
# Out:
# age         0.222853
# sex         0.224469
# cp          0.407075
# trestbps    0.157754
# chol        0.070909
# fbs         0.059186
# restecg     0.183696
# thalach    -0.415040
# exang       0.397057
# oldpeak     0.504092
# slope       0.377957
# ca          0.518909
# thal        0.509923
# num         1.000000
# Name: num, dtype: float64

# %%
df.groupby('num').mean()
# Out:
#            age       sex        cp    trestbps        chol       fbs  \
# num
# 0    52.585366  0.560976  2.792683  129.250000  242.640244  0.140244
# 1    55.381818  0.836364  3.345455  133.254545  249.109091  0.072727
# 2    58.027778  0.805556  3.750000  134.194444  259.277778  0.250000
# 3    56.000000  0.800000  3.771429  135.457143  246.457143  0.228571
# 4    59.692308  0.846154  3.692308  138.769231  253.384615  0.076923
#
#       restecg     thalach     exang   oldpeak     slope        ca      thal
# num
# 0    0.835366  158.378049  0.140244  0.586585  1.408537  0.273292  3.797546
# 1    1.163636  145.927273  0.454545  1.005455  1.636364  0.740741  5.345455
# 2    0.916667  135.583333  0.611111  1.780556  1.888889  1.222222  6.028571
# 3    1.285714  132.057143  0.657143  1.962857  1.971429  1.457143  6.285714
# 4    1.615385  140.615385  0.461538  2.361538  2.076923  1.692308  6.230769

# %%
df.groupby('sex').mean()
# Out:
#            age        cp    trestbps        chol       fbs   restecg  \
# sex
# 0    55.721649  3.144330  133.340206  261.752577  0.123711  0.958763
# 1    53.834951  3.165049  130.912621  239.601942  0.160194  1.004854
#
#         thalach     exang   oldpeak     slope        ca      thal       num
# sex
# 0    151.226804  0.226804  0.867010  1.567010  0.546392  3.656250  0.536082
# 1    148.844660  0.373786  1.120874  1.616505  0.732673  5.239024  1.126214

# %%
sns.lineplot(df.groupby('num').mean())
# Out:
# <Axes: xlabel='num'>

# %%
plt.figure(figsize=(15, 10))
sns.boxplot(df)
# Out:
# <Axes: >

# %%
df[df['chol'] > 400]
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 48    65    0   3       140   417    1        2      157      0      0.8
# 121   63    0   4       150   407    0        2      154      0      4.0
# 152   67    0   3       115   564    0        2      160      0      1.6
# 181   56    0   4       134   409    0        2      150      1      1.9
#
#      slope   ca  thal  num
# 48       1  1.0   3.0    0
# 121      2  3.0   7.0    4
# 152      2  0.0   7.0    0
# 181      2  2.0   7.0    2

# %%
df[df['thalach'] < 100]
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 72    62    1   4       120   267    0        0       99      1      1.8
# 114   62    0   3       130   263    0        0       97      0      1.2
# 154   64    1   4       120   246    0        2       96      1      2.2
# 175   57    1   4       152   274    0        0       88      1      1.2
# 223   53    1   4       123   282    0        0       95      1      2.0
# 244   60    0   3       120   178    1        0       96      0      0.0
# 245   67    1   4       120   237    0        0       71      0      1.0
# 296   59    1   4       164   176    1        2       90      0      1.0
#
#      slope   ca  thal  num
# 72       2  2.0   7.0    1
# 114      2  1.0   7.0    2
# 154      3  1.0   3.0    3
# 175      2  1.0   7.0    1
# 223      2  2.0   7.0    3
# 244      1  0.0   3.0    0
# 245      2  0.0   3.0    2
# 296      2  2.0   6.0    3

# %%
sns.histplot(df['num'], bins=50, kde=True, stat='count')
# Out:
# <Axes: xlabel='num', ylabel='Count'>

# %%
sns.histplot(df['sex'], bins=50, kde=True, stat='count')
# Out:
# <Axes: xlabel='sex', ylabel='Count'>

# %%
sns.histplot(df['age'], bins=50, kde=True, stat='count')
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %% [markdown]
# ### Handling missing values

# %%
import pandas as pd
import numpy as np
from sklearn.impute import SimpleImputer

imputer = SimpleImputer(missing_values=np.nan, strategy='most_frequent')
columns = ['ca', 'thal']
df_imputed = pd.DataFrame(imputer.fit_transform(X[columns]), columns=columns)

for column in X.columns:
    if column not in columns:
        df_imputed[column] = X[column]
    else:
        df_imputed[column] = df_imputed[column].astype('int64')
        
    
df_imputed['num'] = y
print(df_imputed.head())
df_imputed.to_csv("data/heart_disease.csv", index=False)
# Out:
#    ca  thal  age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  \
# 0   0     6   63    1   1       145   233    1        2      150      0
# 1   3     3   67    1   4       160   286    0        2      108      1
# 2   2     7   67    1   4       120   229    0        2      129      1
# 3   0     3   37    1   3       130   250    0        0      187      0
# 4   0     3   41    0   2       130   204    0        2      172      0
#
#    oldpeak  slope  num
# 0      2.3      3    0
# 1      1.5      2    2
# 2      2.6      2    1
# 3      3.5      3    0
# 4      1.4      1    0

# %% [markdown]
# ### Scaling the data

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaled_columns= ['age', 'trestbps', 'chol', 'thalach','oldpeak']
df_imputed[scaled_columns] = scaler.fit_transform(df_imputed[scaled_columns])

df_imputed.head()
# Out:
#    ca  thal       age  sex  cp  trestbps      chol  fbs  restecg   thalach  \
# 0   0     6  0.948726    1   1  0.757525 -0.264900    1        2  0.017197
# 1   3     3  1.392002    1   4  1.611220  0.760415    0        2 -1.821905
# 2   2     7  1.392002    1   4 -0.665300 -0.342283    0        2 -0.902354
# 3   0     3 -1.932564    1   3 -0.096170  0.063974    0        0  1.637359
# 4   0     3 -1.489288    0   2 -0.096170 -0.825922    0        2  0.980537
#
#    exang   oldpeak  slope  num
# 0      0  1.087338      3    0
# 1      1  0.397182      2    2
# 2      1  1.346147      2    1
# 3      0  2.122573      3    0
# 4      0  0.310912      1    0

# %% [markdown]
# ### more EDA

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize = (10,10))
sns.heatmap(df_imputed.corr(), annot=True, cmap='coolwarm')
# Out:
# <Axes: >

# %%
sns.scatterplot(x=df_imputed['chol'], y=df_imputed['num'])
# Out:
# <Axes: xlabel='chol', ylabel='num'>

# %%
sns.lineplot(x=df_imputed['ca'], y=df_imputed['num'])
# Out:
# <Axes: xlabel='ca', ylabel='num'>

# %%
sns.lineplot(x=df_imputed['thal'], y=df_imputed['num'])
# Out:
# <Axes: xlabel='thal', ylabel='num'>

# %%
sns.histplot(df_imputed['num'])
# Out:
# <Axes: xlabel='num', ylabel='Count'>

# %%
sns.boxplot(df_imputed[['chol','ca', 'thal', 'num', 'trestbps','oldpeak', 'exang']])
# Out:
# <Axes: >

# %%
sns.lineplot(x=df_imputed['oldpeak'], y=df_imputed['num'])
# Out:
# <Axes: xlabel='oldpeak', ylabel='num'>

# %%
sns.lineplot(x=df_imputed['exang'], y=df_imputed['num'])
# Out:
# <Axes: xlabel='exang', ylabel='num'>

# %%
sns.violinplot(df_imputed[['chol','ca', 'thal', 'num', 'trestbps','oldpeak', 'exang']])
# Out:
# <Axes: >

# %%
sns.histplot(df_imputed['age'])
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
sns.histplot(df_imputed['thalach'])
# Out:
# <Axes: xlabel='thalach', ylabel='Count'>

# %% [markdown]
# Dropping this row for being an unuseful outlier

# %%
df_imputed.drop(152, axis=0, inplace=True)

# %% [markdown]
# ### Saving the final preprocessed data

# %%
df_imputed.to_csv("data/heart_disease.csv", index=False)
